# %%
#hide
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#hide
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %cd /content/gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
import os
import cv2
from pathlib import Path
from PIL import Image
from google.colab.patches import cv2_imshow
import numpy as np
import shutil

# %%
video_path='/content/gdrive/My Drive/Charade(1963).mp4'
dest='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/color_frames'
print(os.path.exists(video_path),os.path.exists(dest))
# Out:
# True False

# %%
def video2frame(video_path, dest,no_of_images,start_time_secs=None,crop=None):
    start_frame=0
    if not os.path.exists(dest):
        os.mkdir(dest)

    if os.path.exists(video_path):
        video = cv2.VideoCapture(video_path)
    else:
        print('Video not found')
        return
    if start_time_secs is not None:
        fps=video.get(cv2.CAP_PROP_FPS)
        print(fps)
        start_frame = int(start_time_secs*fps)

    count=0
    frame=0
    run=True
    while run:
        try:
            ret,image=video.read()
            if not ret:run=False
            if ret:
                frame+=1
                if frame>=start_frame and frame%3==0:
                    if crop is not None: 
                        x,w,y,h = crop
                        image=image[x:w,y:h]
                    count+=1
                    img = cv2.resize(image,(512,512),interpolation=cv2.INTER_AREA)
                    cv2.imwrite(f'{dest}/{count}.jpg',img,[int(cv2.IMWRITE_JPEG_QUALITY),100])
                    print(f"{count}.jpg saved successfully")
                if count==no_of_images:run=False
        except Exception as e:pass

# %%
video2frame(video_path,dest,6000,start_time_secs=4*60)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1001.jpg saved successfully
# 1002.jpg saved successfully
# 1003.jpg saved successfully
# 1004.jpg saved successfully
# 1005.jpg saved successfully
# 1006.jpg saved successfully
# 1007.jpg saved successfully
# 1008.jpg saved successfully
# 1009.jpg saved successfully
# 1010.jpg saved successfully
# 1011.jpg saved successfully
# 1012.jpg saved successfully
# 1013.jpg saved successfully
# 1014.jpg saved successfully
# 1015.jpg saved successfully
# 1016.jpg saved successfully
# 1017.jpg saved successfully
# 1018.jpg saved successfully
# 1019.jpg saved successfully
# 1020.jpg saved successfully
# 1021.jpg saved successfully
# 1022.jpg saved successfully
# 1023.jpg saved successfully
# 1024.jpg saved successfully
# 1025.jpg saved successfully
# 1026.jpg saved successfully
# 1027.jpg saved successfully
# 1028.jpg saved successfully
# 1029.jpg saved successfully
# 1030.jpg saved successfully
# 1031.jpg saved successfully
# ...

# %%
len(list(os.listdir(dest)))
# Out:
# 3058

# %%
video_path='/content/gdrive/My Drive/TheGoldRush1925.mp4'
dest='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/black_white_frames'
print(os.path.exists(video_path),os.path.exists(dest))
# Out:
# True True

# %%
video2frame(video_path,dest,6000,start_time_secs=5*60,crop=(0,480,110,740))
# Out:
# Streaming output truncated to the last 5000 lines.
# 1001.jpg saved successfully
# 1002.jpg saved successfully
# 1003.jpg saved successfully
# 1004.jpg saved successfully
# 1005.jpg saved successfully
# 1006.jpg saved successfully
# 1007.jpg saved successfully
# 1008.jpg saved successfully
# 1009.jpg saved successfully
# 1010.jpg saved successfully
# 1011.jpg saved successfully
# 1012.jpg saved successfully
# 1013.jpg saved successfully
# 1014.jpg saved successfully
# 1015.jpg saved successfully
# 1016.jpg saved successfully
# 1017.jpg saved successfully
# 1018.jpg saved successfully
# 1019.jpg saved successfully
# 1020.jpg saved successfully
# 1021.jpg saved successfully
# 1022.jpg saved successfully
# 1023.jpg saved successfully
# 1024.jpg saved successfully
# 1025.jpg saved successfully
# 1026.jpg saved successfully
# 1027.jpg saved successfully
# 1028.jpg saved successfully
# 1029.jpg saved successfully
# 1030.jpg saved successfully
# 1031.jpg saved successfully
# ...

# %%
len(list(os.listdir(dest)))
# Out:
# 6000

# %%
def move_no_files(source,dest,num_files):
    if not os.path.exists(source): print('Source path not valid');return

    if not os.path.exists(dest): 
        os.mkdir(dest)

    all_files = os.listdir(source)
    total_files=len(all_files)
    
    np.random.shuffle(all_files)
    move_files=all_files[:num_files]
    move_files = [source+'/'+ name for name in move_files]
    print(len(move_files))

    for name in move_files:
        shutil.move(name, dest)
    print(f'Moved {len(move_files)} files to "{dest}" folder ')

# %%
source='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/black_white_frames'
destination='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/black_white_frames_gen'

# %%
move_no_files(source, destination, 3000)
# Out:
# 3000
# Moved 3000 files to "/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/black_white_frames_gen" folder

# %%
source1='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/color_frames'
destination1='/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/color_frames_gen'

# %%
move_no_files(source1, destination1, 3000)
# Out:
# 3000
# Moved 3000 files to "/content/gdrive/My Drive/Colab Notebooks/project_code/image_colorization_cyclegan/data/color_frames_gen" folder
